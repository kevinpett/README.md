# %% [markdown]
# # My jupyter notebook on IBM Watson Studio

# %% [markdown]
# **Kevin Pettit**
#
# Data Analyst

# %% [markdown]
# *I am very interested in data science because the potential is endless and so many more opportunities keep opening up*

# %% [markdown]
# ### This next code will include a simple addition problem

# %%
1+1
# Out:
# 2

# %% [markdown]
# ##### Most popular sports in the US
#
# 1. Football
# 2. Baseball
# 3. Basketball
#
# |Most popular sports in the US|
# |-----------------------------|
# |Football|
# |Baseball|
# |Basketball|
#
# ![Streaming-Sports-America-Share-v2.jpg](attachment:Streaming-Sports-America-Share-v2.jpg)
